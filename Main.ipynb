# %% [markdown]
# GPU 할당 체크

# %%
# !nvidia-smi -L
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# 드라이브 마운트 (굳이 안해도 될 것 같긴 한데, 일단 넣어뒀음

# %%
from google.colab import drive
drive.mount('/content/drive/MyDrive/Colab Notebook/Training/CafeterraceAtNight')

# %% [markdown]
# SG2 설치

# %%
import os
curPath = '/content/drive/MyDrive/Colab Notebooks/Training/CafeterraceAtNight/Setup'
os.chdir(curPath)
targetPath = curPath + '/colab-sg2-ada-pytorch'
if os.path.isdir(targetPath):
  os.chdir(targetPath)
else:
  os.mkdir(targetPath)
  os.chdir(targetPath)
  # !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
  targetPath2 = targetPath + '/stylegan2-ada-pytorch'
  os.chdir(targetPath2)
  os.mkdir(targetPath2 + '/downloads')
  os.mkdir(targetPath2 + '/pretrained')
  os.mkdir(targetPath2 + '/datasets')
  # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/Colab Notebooks/Training/CafeterraceAtNight/Setup/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
# !pip install ninja opensimplex
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 461, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 461 (delta 20), reused 13 (delta 5), pack-reused 418
# Receiving objects: 100% (461/461), 8.41 MiB | 13.15 MiB/s, done.
# Resolving deltas: 100% (245/245), done.
# usage: gdown [-h] [-V] [-O OUTPUT] [-q] [--id] url_or_id
# gdown: error: unrecognized arguments: Notebooks/Training/CafeterraceAtNight/Setup/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
# ...
#      |████████████████████████████████| 112kB 3.9MB/s
# ...

# %% [markdown]
# SG2 깃 업데이트 (불필요)

# %%
os.chdir(targetPath2)
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git pull
# !git stash
# !git checkout origin/main -- train.py generate.py legacy.py closed_form_factorization.py flesh_digression.py apply_factor.py README.md calc_metrics.py training/stylegan2_multi.py training/training_loop.py util/utilgan.py
# Out:
# Already up to date.
# Saved working directory and index state WIP on main: 3d88de9 Save latent_avg in model export
